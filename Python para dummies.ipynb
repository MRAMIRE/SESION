# %%
1+1
# Out:
# 2

# %% [markdown]
# # Introduccion a Python

# %% [markdown]
# Comando para revisar la version de python que tenemos en el equipo

# %%
# !python --version
# Out:
# Python 3.6.9

# %% [markdown]
# Comando para cargue de archivos desde drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Operaciones basicas

# %%
1+1
# Out:
# 2

# %%
10-8
# Out:
# 2

# %%
1*3
# Out:
# 3

# %%
2/2
# Out:
# 1.0

# %%
4%2
# Out:
# 0

# %%
2**2
# Out:
# 4

# %% [markdown]
# Precedencia de operadores

# %%
2+3*5+5
# Out:
# 22

# %% [markdown]
# Los parantesis pueden modificar la precedencia

# %%
(2+3)*(5+5)
# Out:
# 50

# %% [markdown]
# ## Asignacion de valores a variables

# %% [markdown]
# Nombres de las variables no deben empezar con numeros ni caracteres especiales,**No debemos usar ortografia en las variables**

# %%
mi_variable=2

# %%
print(mi_variable)
# Out:
# 2

# %%
x=2
y=1

# %%
z=x+y

# %%
print(z)
# Out:
# 3

# %% [markdown]
# Variable Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
Variable_booleana=True

# %% [markdown]
# Variables de tipo caracter

# %%
'Comilla simple'
# Out:
# 'Comilla simple'

# %%
"Comilla dobles"
# Out:
# 'Comilla dobles'

# %%
'mensaje \' otra comilla'
# Out:
# "mensaje ' otra comilla"

# %% [markdown]
# Indecadenas
#
# Podemos navegar posicicionalmnete la cadena de caracteres por medio de sus indices.

# %%
cadena="Este es el curso de Python"

# %%
cadena[3]
# Out:
# 'e'

# %%
cadena[0:4]
# Out:
# 'Este'

# %%
cadena[::-1]
# Out:
# 'nohtyP ed osruc le se etsE'

# %%
cadena[0:28]
# Out:
# 'Este es el curso de Python'

# %%
cadena[:]
# Out:
# 'Este es el curso de Python'

# %% [markdown]
# **Manejo de listas**

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
['a','b','c']
# Out:
# ['a', 'b', 'c']

# %%
['hola',2,[1,2]]
# Out:
# ['hola', 2, [1, 2]]

# %%
mi_lista=['a','b','c']

# %%
print(mi_lista)
# Out:
# ['a', 'b', 'c']

# %%
mi_lista.append('d')

# %%
mi_lista
# Out:
# ['a', 'b', 'c', 'd']

# %%
mi_lista.remove('c')

# %%
mi_lista
# Out:
# ['a', 'b', 'd']

# %%
del mi_lista[1]

# %%
mi_lista
# Out:
# ['a', 'd']

# %%
mi_lista.pop(1)
# Out:
# 'd'

# %%
mi_lista
# Out:
# ['a']

# %%
mi_lista=['a','b','c','d']

# %%
mi_lista[2:4]
# Out:
# ['c', 'd']

# %%
mi_lista[1:]
# Out:
# ['b', 'c', 'd']

# %%
mi_lista[0]='A'

# %%
mi_lista
# Out:
# ['A', 'b', 'c', 'd']

# %%
anidada=[1,2,[3,4],5]

# %%
anidada[2]
# Out:
# [3, 4]

# %%
anidada[2][-1]
# Out:
# 4

# %%
anidada_2=[1,2,3,[4,5,['Objetivo']]]

# %%
anidada_2[3]
# Out:
# [4, 5, ['Objetivo']]

# %%
anidada_2[3][2]
# Out:
# ['Objetivo']

# %%
anidada_2[3][2][0][0:3]
# Out:
# 'Obj'
